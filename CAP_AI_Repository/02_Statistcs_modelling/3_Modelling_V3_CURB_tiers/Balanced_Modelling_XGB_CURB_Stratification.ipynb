# %%
# %reset -f
import pandas as pd
import numpy as np

from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

import re, sqlite3, pickle, time, datetime, random, sys
# sys.path is a list of absolute path strings
sys.path.append('/home/d/dlr10/Documents/02_Statitics_modelling/0_FunctionsScripts')
import Loading_Data_Functions as load_fn
import FineTuning_Functions as FineTuning
import Learning_Curves_Functions as LearningCurves

pd.options.display.float_format = '{:,.3f}'.format
# Out:
# 2022-10-15 15:43:36.375259: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/local/apps/gcc/8.2.0/lib:/cm/local/apps/gcc/8.2.0/lib64:/cm/local/apps/torque/6.1.3/lib
# 2022-10-15 15:43:36.375292: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # 0. Functions

# %% [markdown]
# ### 0.1. Encoding functions

# %%
############################################################
# ENCODING CATEGORICAL VARIABLES WITH TARGET ENCODER OR NORMALISE CONTINUOUS VARIABLES
# https://towardsdatascience.com/target-encoding-and-bayesian-target-encoding-5c6a6c58ae8c
############################################################
def target_encoder_Binary(column, target, X_data):
    df = []
    for cat in X_data[column].unique():
        row = []
        row.append(len(X_data[(X_data[target]==0) & (X_data[column] == cat)]))
        row.append(len(X_data[(X_data[target]==1) & (X_data[column] == cat)]))
        df.append(row)
    df = pd.DataFrame(df, index = X_data[column].unique(), columns = ['0','1'])
    df['prob'] = df['1']/(df['1']+df['0'])
    col_encod = X_data[column].map(dict(zip(df.index, df['prob'])))
    return col_encod, df
############################################################
def Normalise_n_encode_train_set(X_data, feat_list, data_types):
    encoder = []
    X_data_norm_2 = pd.DataFrame()
    for feat in feat_list:
        if data_types[feat] == 'Continuous':
            X_data_feat = X_data[feat]
            mean        = X_data_feat.mean()
            std         = X_data_feat.std()
            X_data_norm_2[feat] = (X_data_feat - mean)/std
            encoder.append([feat, data_types[feat], [mean, std]])
        elif data_types[feat] == 'Categorical':
            X_data_norm_2[feat],df = target_encoder_Binary(feat, 'Mortality', X_data)
            encoder.append([feat, data_types[feat], df])
        elif data_types[feat] == 'Binary':
            X_data_norm_2[feat] = X_data[feat].copy()
            encoder.append([feat, data_types[feat], ""])
    encoder =pd.DataFrame(encoder, columns = ['feature','type','parameters'])
    return X_data_norm_2,encoder
############################################################
def Normalise_n_encode_val_set(val_data, norm_encoder, feat_list, data_types):
    X_data_norm_2 = pd.DataFrame()
    for feat in feat_list:
        if data_types[feat] == 'Continuous':
            X_data_feat = val_data[feat]
            mean, std   = norm_encoder[norm_encoder['feature'] == feat].iloc[0]['parameters']
            X_data_norm_2[feat] = (X_data_feat - mean)/std

        elif data_types[feat] == 'Categorical':
            df = norm_encoder[norm_encoder['feature'] == feat].iloc[0]['parameters']
            X_data_norm_2[feat] = val_data[feat].map(dict(zip(df.index, df['prob'])))
            X_data_norm_2[feat] = X_data_norm_2[feat].fillna(0)
        elif data_types[feat] == 'Binary':
            X_data_norm_2[feat] = val_data[feat].copy()
    return X_data_norm_2
############################################################

# %% [markdown]
# ### 0.2. Split Data Function

# %%
def train_valid_sets(X_train_set, X_valid_set):
    #######################################
    ### BALANCED DATA
    #######################################
    random.seed(2)
    X_0 = X_train_set[X_train_set['Mortality'] == 0]
    X_1 = X_train_set[X_train_set['Mortality'] == 1]

    list_X_0 = random.sample(range(len(X_0)),len(X_1))
    X_0_2 = X_0.iloc[list_X_0]

    X_data_bal = pd.concat([X_1,X_0_2])
    
    #######################################
    ### SPLIT DATA
    #######################################
    
    train_set = X_data_bal
    valid_set = X_valid_set

    print('total admissions 16 18', len(X_train_set))
    print('total admissions 19 20', len(X_valid_set))
    print('X_train', len(train_set))
    print('Admissions neg (mortal - class = 0):', len(train_set[train_set['Mortality']==0]),
          'Admissions pos (recover- class = 1):', len(train_set[train_set['Mortality']==1]))
    print('X_valid', len(valid_set))
    print('Admissions neg (mortal - class = 0):', len(valid_set[valid_set['Mortality']==0]), 
          'Admissions pos (recover- class = 1):', len(valid_set[valid_set['Mortality']==1]))
    return train_set, valid_set

# %% [markdown]
# ### 0.3. Encoding Data Function

# %%
def encoding_data(train_set, valid_set, feat_list, data_types):
    ############################################################
    train_set_norm, encoder = Normalise_n_encode_train_set(train_set, feat_list, data_types)
    valid_set_norm          = Normalise_n_encode_val_set(valid_set, encoder, feat_list, data_types)
    print("==========================================================================================================")
    print('----------------------------------TRAIN SET---------------------------------------------------------------')
    print("==========================================================================================================")
    display(train_set.head(4))
    display(train_set_norm.head(4))
    print("==========================================================================================================")
    print('----------------------------------VALIDATION SET----------------------------------------------------------')
    print("==========================================================================================================")
    display(valid_set.head(4))
    display(valid_set_norm.head(4))
    display(encoder)
    return train_set_norm, valid_set_norm, encoder

# %% [markdown]
# # 1. Load Data

# %%
t = time.time()
path = r'/home/d/dlr10/Documents/02_Statitics_modelling/DataSets/'

X_data_16_18 = pickle.load(open(path + 'df_first_curb_2016_18.pickle','rb'))
X_data_19_20 = pickle.load(open(path + 'df_first_curb_2019_20.pickle','rb'))


print("=================================FIRST RECORDED SAMPLE ADMISSION=================================")
print("-------------------------------------- 2016 - 2018 ----------------------------------------------")
display(X_data_16_18[0].head(3))
print("")
print("-------------------------------------- 2019 - 2020 ----------------------------------------------")
display(X_data_19_20[0].head(3))

print("Elapsed time:", time.time()-t)
# Out:
# =================================FIRST RECORDED SAMPLE ADMISSION=================================
# -------------------------------------- 2016 - 2018 ----------------------------------------------
#     admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0       38552641 34.000   11     118.000       39.200 100.000 55.000
# 144     37660212 24.000    7      75.000       37.000 100.000 54.000
# 288     67150633 24.000    4      75.000       37.800 117.000 72.000
#
#      Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0               96.000        1.000          0   -1          3            54
# 144             95.000        1.000          0   -1          0            47
# 288             92.000        1.000          1   -1          0            84
#
#      Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0               2             1           1.000          0
# 144             0             0           0.000          0
# 288             8             0           0.000          0
# -------------------------------------- 2019 - 2020 ----------------------------------------------
#     admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0       25298427 18.000    3      88.000       37.000  76.000 54.000
# 144     31669457 22.000    9     135.000       38.500 148.000 97.000
# 288     52534553 16.000    2      66.000       37.100 136.000 84.000
#
#      Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0              100.000        0.000          0   -1          0            64
# 144             95.000        1.000          0   -1          0            36
# 288            100.000        1.000          0    1          1            84
#
#      Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0               6             0           1.000          0
# 144             0             0           0.000          0
# 288             3             0           0.000          0
# Elapsed time: 0.03276324272155762

# %%
feat_list = X_data_16_18[0].columns.tolist()
feat_list = feat_list[1:-1]
print(feat_list)
print("Number of features:",len(feat_list))
# Out:
# ['rr', 'ews', 'heart_rate', 'temperature', 'sbp', 'dbp', 'Oxygen_Saturation', 'Assisted_O2', 'Confusion', 'sex', 'ethnicity', 'age_at_admin', 'Comorb_score', 'Spcfc_Comorb', 'had_Prev_admin']
# Number of features: 15

# %%
# Loading the CSV with types
data_types = pd.read_csv('/home/d/dlr10/Documents/02_Statitics_modelling/2_Statistics/csv_Type_variables.csv')
# Dictionary of features and types
data_types = data_types.set_index('Variable').to_dict()['Type']

# %%
############################################################
# Results DataFrame Creation
############################################################

# %% [markdown]
# # Modelling parameters XGBoost Classfier

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from xgboost import XGBClassifier
t = time.time()
# define model
model = XGBClassifier(use_label_encoder=False, objective = 'binary:logistic', eval_metric = 'auc')
# define grid
weights = [1, 2,3,4,5, 8, 10, 25, 50, 75, 99, 100, 500]
#weights = [1]
param_grid = dict(scale_pos_weight=weights)
scoring = {"AUC": "roc_auc", "Recall": "recall"}
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=scoring, refit = "Recall")

# %% [markdown]
# # 2. Modelling XGBoost classifier

# %%
def train_grid_XGB_model(train_set, valid_set, X_train_set, X_valid_set, grid, feat_list):
    df_results_train = pd.DataFrame()
    df_results       = pd.DataFrame()
    dict_fpr_tpr     = {}
    X_train = np.array(train_set[feat_list]); Y_train = np.array(X_train_set['Mortality'])
    X_valid = np.array(valid_set[feat_list]); Y_valid = np.array(X_valid_set['Mortality'])
    #################################################################
    #################################################################
    # TRAINING THE MODEL
    #################################################################
    t = time.time()
    # execute the grid search
    grid_result = grid.fit(X_train, Y_train)
    # report the best configuration
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    # report all configurations
    auc_means = grid_result.cv_results_['mean_test_AUC']
    rcl_means = grid_result.cv_results_['mean_test_Recall']
    params    = grid_result.cv_results_['params']
    print("AUC    (call)")
    for mean, rcl, param in zip(auc_means, rcl_means, params):
        print("%f (%f) with: %r" % (mean, rcl, param))    
    df_results_train['NoF_auc'] = auc_means
    df_results_train['NoF_rcl'] = rcl_means
    print("")
    print("time elapased training: ", time.time()-t)
    #################################################################
    #################################################################
    # results - Model Validation
    #################################################################

    y_scores  = grid.predict(X_valid)
    y_predict = FineTuning.adjusted_classes(y_scores, 0.5)
    y_proba   = grid.predict_proba(X_valid)[:,1]
    df_results, fpr_tpr = LearningCurves.results_precision_recall_cm(Y_valid, y_predict, y_proba, fig_size = None)
    plt.show()
    dict_fpr_tpr['NoF'] = fpr_tpr
    df_results = df_results.set_index(pd.Series('NoF'))
    display(df_results)
    return [df_results_train, df_results, dict_fpr_tpr]

# %% [markdown]
# # CURB65 Group 1

# %%
X_train_set = X_data_16_18[0]
X_valid_set = X_data_19_20[0]
train_set, valid_set = train_valid_sets(X_train_set, X_valid_set)
print("")
train_set_norm, valid_set_norm, _ = encoding_data(train_set, valid_set, feat_list, data_types)
# Out:
# total admissions 16 18 1161
# total admissions 19 20 409
# X_train 102
# Admissions neg (mortal - class = 0): 51 Admissions pos (recover- class = 1): 51
# X_valid 409
# Admissions neg (mortal - class = 0): 378 Admissions pos (recover- class = 1): 31
#
# ==========================================================================================================
# ----------------------------------TRAIN SET---------------------------------------------------------------
# ==========================================================================================================
#      admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 576      31151576 24.000    4      86.000       38.000 115.000 77.000
# 864      62984364 22.000    5      85.000       37.000 106.000 62.000
# 6624     12588258 18.000    2      95.000       36.400 111.000 85.000
# 8784      3833706 26.000    6     110.000       37.700 140.000 79.000
#
#       Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 576              97.000        1.000          0   -1          0            92
# 864              96.000        1.000          0    1          0            44
# 6624             95.000        1.000          1   -1          0            82
# 8784            100.000        1.000          0   -1          0            67
#
#       Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 576              2             1           0.000          1
# 864              0             1           0.000          1
# 6624             0             0           1.000          1
# 8784             3             1           0.000          1
#          rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 576   0.291 0.500      -0.829        0.931 -0.683 -0.049              0.623
# 864  -0.145 0.600      -0.880       -0.284 -1.069 -1.198              0.342
# 6624 -1.017 0.545      -0.370       -1.013 -0.855  0.563              0.061
# 8784  0.727 0.429       0.394        0.566  0.387  0.104              1.467
#
#       Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 576         1.000          0   -1      0.517         1.645        -0.234
# 864         1.000          0    1      0.517        -1.100        -0.716
# 6624        1.000          1   -1      0.517         1.073        -0.716
# 8784        1.000          0   -1      0.517         0.215         0.007
#
#       Spcfc_Comorb  had_Prev_admin
# 576              1           0.000
# 864              1           0.000
# 6624             0           1.000
# 8784             1           0.000
# ==========================================================================================================
# ----------------------------------VALIDATION SET----------------------------------------------------------
# ==========================================================================================================
#     admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0       25298427 18.000    3      88.000       37.000  76.000 54.000
# 144     31669457 22.000    9     135.000       38.500 148.000 97.000
# 288     52534553 16.000    2      66.000       37.100 136.000 84.000
# 432     21124330 20.000    4      91.000       37.100 123.000 76.000
#
#      Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0              100.000        0.000          0   -1          0            64
# 144             95.000        1.000          0   -1          0            36
# 288            100.000        1.000          0    1          1            84
# 432             94.000        1.000          0    1          0            67
#
#      Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0               6             0           1.000          0
# 144             0             0           0.000          0
# 288             3             0           0.000          0
# 432             0             0           1.000          1
#         rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 0   -1.017 0.214      -0.727       -0.284 -2.354 -1.811              1.467
# 144 -0.145 0.500       1.668        1.538  0.730  1.482              0.061
# 288 -1.454 0.545      -1.848       -0.163  0.216  0.487              1.467
# 432 -0.581 0.500      -0.574       -0.163 -0.341 -0.126             -0.221
#
#      Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 0          0.000          0   -1      0.517         0.044         0.730
# 144        1.000          0   -1      0.517        -1.558        -0.716
# 288        1.000          0    1      0.250         1.188         0.007
# 432        1.000          0    1      0.517         0.215        -0.716
#
#      Spcfc_Comorb  had_Prev_admin
# 0               0           1.000
# 144             0           0.000
# 288             0           0.000
# 432             0           1.000
#               feature         type  \
# 0                  rr   Continuous
# 1                 ews  Categorical
# 2          heart_rate   Continuous
# 3         temperature   Continuous
# 4                 sbp   Continuous
# 5                 dbp   Continuous
# 6   Oxygen_Saturation   Continuous
# 7         Assisted_O2       Binary
# 8           Confusion       Binary
# 9                 sex       Binary
# 10          ethnicity  Categorical
# 11       age_at_admin   Continuous
# 12       Comorb_score   Continuous
# 13       Spcfc_Comorb       Binary
# 14     had_Prev_admin       Binary
#
#                                            parameters
# 0              [22.666666666666668, 4.58653503533583]
# 1        0  1  prob
# 4    5  5 0.500
# 5    6  9 0.60...
# 2            [102.26960784313725, 19.626673047009145]
# 3            [37.233823529411765, 0.8232139913051096]
# 4              [130.9558823529412, 23.34842659498215]
# 5              [77.6421568627451, 13.057825970055635]
# 6              [94.7843137254902, 3.5554377568980287]
# 7
# 8
# 9
# 10      0   1  prob
# 0  42  45 0.517
# 3   4   2 0.33...
# 11            [63.23529411764706, 17.481631927916037]
# 12            [2.9705882352941178, 4.149331050350741]
# 13
# 14

# %%
print("############### Results without encoding ##############")
results1     = train_grid_XGB_model(train_set, valid_set, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results without encoding ##############
# Best: 0.915152 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.729091 (0.690909) with: {'scale_pos_weight': 1}
# 0.719879 (0.691515) with: {'scale_pos_weight': 2}
# 0.720970 (0.769697) with: {'scale_pos_weight': 3}
# 0.733091 (0.750303) with: {'scale_pos_weight': 4}
# 0.716970 (0.744848) with: {'scale_pos_weight': 5}
# 0.732061 (0.769697) with: {'scale_pos_weight': 8}
# 0.729939 (0.763636) with: {'scale_pos_weight': 10}
# 0.727030 (0.790303) with: {'scale_pos_weight': 25}
# 0.735394 (0.815758) with: {'scale_pos_weight': 50}
# 0.730788 (0.842424) with: {'scale_pos_weight': 75}
# 0.742485 (0.835758) with: {'scale_pos_weight': 99}
# 0.748000 (0.836364) with: {'scale_pos_weight': 100}
# 0.743455 (0.915152) with: {'scale_pos_weight': 500}
#
# time elapased training:  1030.4487566947937
# Confidence interval for the score: [0.591 - 0.733]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.089   1.000     0.164     0.227 0.666  0.722  [0.59, 0.733]

# %%
print("############### Results encoded data ##############")
results1_enc = train_grid_XGB_model(train_set_norm, valid_set_norm, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results encoded data ##############
# Best: 0.887879 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.784788 (0.742424) with: {'scale_pos_weight': 1}
# 0.793333 (0.795758) with: {'scale_pos_weight': 2}
# 0.793152 (0.796364) with: {'scale_pos_weight': 3}
# 0.781576 (0.795758) with: {'scale_pos_weight': 4}
# 0.786424 (0.808485) with: {'scale_pos_weight': 5}
# 0.792788 (0.829091) with: {'scale_pos_weight': 8}
# 0.788606 (0.841818) with: {'scale_pos_weight': 10}
# 0.785758 (0.835758) with: {'scale_pos_weight': 25}
# 0.777030 (0.855758) with: {'scale_pos_weight': 50}
# 0.772303 (0.855152) with: {'scale_pos_weight': 75}
# 0.775030 (0.848485) with: {'scale_pos_weight': 99}
# 0.777697 (0.855152) with: {'scale_pos_weight': 100}
# 0.780121 (0.887879) with: {'scale_pos_weight': 500}
#
# time elapased training:  996.2699859142303
# Confidence interval for the score: [0.633 - 0.776]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.098   1.000     0.179     0.306 0.709  0.636  [0.63, 0.776]

# %% [markdown]
# # CURB65 Group 2

# %%
X_train_set = X_data_16_18[1]
X_valid_set = X_data_19_20[1]
train_set, valid_set = train_valid_sets(X_train_set, X_valid_set)
print("")
train_set_norm, valid_set_norm, _ = encoding_data(train_set, valid_set, feat_list, data_types)
# Out:
# total admissions 16 18 1037
# total admissions 19 20 389
# X_train 222
# Admissions neg (mortal - class = 0): 111 Admissions pos (recover- class = 1): 111
# X_valid 389
# Admissions neg (mortal - class = 0): 328 Admissions pos (recover- class = 1): 61
#
# ==========================================================================================================
# ----------------------------------TRAIN SET---------------------------------------------------------------
# ==========================================================================================================
#      admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 144      73017510 22.000   10      66.000       36.000  95.000 60.000
# 288      76521119 23.000    8      82.000       37.300 103.000 67.000
# 1008     66176251 18.000    2      66.000       36.300 135.000 62.000
# 1296     25935498 20.000    4      86.000       36.400  92.000 64.000
#
#       Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 144              96.000        1.000          1   -1          0            90
# 288              90.000        1.000          0   -1          0            72
# 1008             98.000        1.000          0    1          3            88
# 1296             99.000        1.000          0   -1          0            84
#
#       Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 144              0             1           1.000          1
# 288              9             0           0.000          1
# 1008            19             1           0.000          1
# 1296            22             0           1.000          1
#          rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 144  -0.085 0.636      -1.313       -1.115 -1.391 -0.864              0.427
# 288   0.131 0.529      -0.520        0.260 -1.026 -0.351             -1.085
# 1008 -0.947 0.615      -1.313       -0.798  0.436 -0.717              0.930
# 1296 -0.516 0.484      -0.322       -0.692 -1.528 -0.571              1.182
#
#       Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 144         1.000          1   -1      0.511         1.071        -0.775
# 288         1.000          0   -1      0.511        -0.507         0.544
# 1008        1.000          0    1      0.250         0.896         2.010
# 1296        1.000          0   -1      0.511         0.545         2.449
#
#       Spcfc_Comorb  had_Prev_admin
# 144              1           1.000
# 288              0           0.000
# 1008             1           0.000
# 1296             0           1.000
# ==========================================================================================================
# ----------------------------------VALIDATION SET----------------------------------------------------------
# ==========================================================================================================
#     admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0       88572864 16.000    6      73.000       34.900  90.000 44.000
# 144     62751181 24.000    7     114.000       39.000 137.000 81.000
# 288     21357495 24.000    2      71.000       37.900 150.000 66.000
# 432     83262936 16.000    1      87.000       36.800 137.000 72.000
#
#      Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0               96.000        0.000          1   -1          1            93
# 144             98.000        1.000          0    1          0            67
# 288             96.000        0.000          0   -1          0            84
# 432             95.000        0.000          0    1          0            89
#
#      Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0               6             1           1.000          1
# 144             0             0           1.000          0
# 288             8             1           1.000          0
# 432             0             0           1.000          0
#         rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 0   -1.377 0.556      -0.966       -2.279 -1.620 -2.037              0.427
# 144  0.346 0.417       1.066        2.059  0.527  0.676              0.930
# 288  0.346 0.615      -1.066        0.895  1.121 -0.424              0.427
# 432 -1.377 0.333      -0.272       -0.269  0.527  0.016              0.175
#
#      Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 0          0.000          1   -1      0.500         1.334         0.104
# 144        1.000          0    1      0.511        -0.945        -0.775
# 288        0.000          0   -1      0.511         0.545         0.397
# 432        0.000          0    1      0.511         0.984        -0.775
#
#      Spcfc_Comorb  had_Prev_admin
# 0               1           1.000
# 144             0           1.000
# 288             1           1.000
# 432             0           1.000
#               feature         type  \
# 0                  rr   Continuous
# 1                 ews  Categorical
# 2          heart_rate   Continuous
# 3         temperature   Continuous
# 4                 sbp   Continuous
# 5                 dbp   Continuous
# 6   Oxygen_Saturation   Continuous
# 7         Assisted_O2       Binary
# 8           Confusion       Binary
# 9                 sex       Binary
# 10          ethnicity  Categorical
# 11       age_at_admin   Continuous
# 12       Comorb_score   Continuous
# 13       Spcfc_Comorb       Binary
# 14     had_Prev_admin       Binary
#
#                                            parameters
# 0             [22.394144144144143, 4.642301264341017]
# 1        0   1  prob
# 10   4   7 0.636
# 8    8   9 0...
# 2              [92.49549549549549, 20.17345546527619]
# 3             [37.05382882882883, 0.9450017249511311]
# 4            [125.45945945945945, 21.891405691398802]
# 5             [71.78603603603604, 13.639523138867764]
# 6              [94.30630630630631, 3.970006993150189]
# 7
# 8
# 9
# 10       0   1  prob
# 0   93  97 0.511
# 3   12   4 0...
# 11            [77.77927927927928, 11.408138851600501]
# 12             [5.288288288288288, 6.823419064920336]
# 13
# 14

# %%
print("############### Results without encoding ##############")
results2     = train_grid_XGB_model(train_set, valid_set, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results without encoding ##############
# Best: 0.825955 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.712828 (0.670092) with: {'scale_pos_weight': 1}
# 0.717858 (0.700132) with: {'scale_pos_weight': 2}
# 0.720344 (0.703162) with: {'scale_pos_weight': 3}
# 0.707258 (0.720949) with: {'scale_pos_weight': 4}
# 0.708115 (0.718050) with: {'scale_pos_weight': 5}
# 0.711349 (0.741634) with: {'scale_pos_weight': 8}
# 0.711031 (0.751120) with: {'scale_pos_weight': 10}
# 0.719236 (0.777470) with: {'scale_pos_weight': 25}
# 0.709941 (0.789723) with: {'scale_pos_weight': 50}
# 0.714642 (0.819631) with: {'scale_pos_weight': 75}
# 0.697425 (0.807773) with: {'scale_pos_weight': 99}
# 0.697886 (0.784058) with: {'scale_pos_weight': 100}
# 0.705516 (0.825955) with: {'scale_pos_weight': 500}
#
# time elapased training:  1450.6122643947601
# Confidence interval for the score: [0.568 - 0.698]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.177   0.918     0.297     0.319 0.631  0.622  [0.57, 0.698]

# %%
print("############### Results encoded data ##############")
results2_enc = train_grid_XGB_model(train_set_norm, valid_set_norm, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results encoded data ##############
# Best: 0.849539 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.712322 (0.672991) with: {'scale_pos_weight': 1}
# 0.716182 (0.693939) with: {'scale_pos_weight': 2}
# 0.714247 (0.726877) with: {'scale_pos_weight': 3}
# 0.720368 (0.732806) with: {'scale_pos_weight': 4}
# 0.718062 (0.735705) with: {'scale_pos_weight': 5}
# 0.716936 (0.774835) with: {'scale_pos_weight': 8}
# 0.727542 (0.754018) with: {'scale_pos_weight': 10}
# 0.730944 (0.780764) with: {'scale_pos_weight': 25}
# 0.713840 (0.795652) with: {'scale_pos_weight': 50}
# 0.720775 (0.805007) with: {'scale_pos_weight': 75}
# 0.712606 (0.820158) with: {'scale_pos_weight': 99}
# 0.723224 (0.807773) with: {'scale_pos_weight': 100}
# 0.721518 (0.849539) with: {'scale_pos_weight': 500}
#
# time elapased training:  1441.0715687274933
# Confidence interval for the score: [0.545 - 0.675]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.173   0.885     0.290     0.319 0.610  0.606  [0.54, 0.675]

# %% [markdown]
# # CURB65 Group 3

# %%
X_train_set = X_data_16_18[2]
X_valid_set = X_data_19_20[2]
train_set, valid_set = train_valid_sets(X_train_set, X_valid_set)
print("")
train_set_norm, valid_set_norm, _ = encoding_data(train_set, valid_set, feat_list, data_types)
# Out:
# total admissions 16 18 1095
# total admissions 19 20 259
# X_train 394
# Admissions neg (mortal - class = 0): 197 Admissions pos (recover- class = 1): 197
# X_valid 259
# Admissions neg (mortal - class = 0): 206 Admissions pos (recover- class = 1): 53
#
# ==========================================================================================================
# ----------------------------------TRAIN SET---------------------------------------------------------------
# ==========================================================================================================
#      admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0        79958796 22.000    8      91.000       36.300 140.000 57.000
# 144      54340823 38.000    7      95.000       36.100 136.000 88.000
# 1440     58516806 23.000    8     109.000       37.300  89.000 51.000
# 2016     68938901 28.000    8      62.000       35.700 172.000 70.000
#
#       Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0                90.000        1.000          0   -1          0            79
# 144              94.000        1.000          0   -1          0            91
# 1440             97.000        1.000          0    1          3            87
# 2016             94.000        1.000          1    1          0           100
#
#       Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0                8             0           0.000          1
# 144              0             1           1.000          1
# 1440             6             0           0.000          1
# 2016             4             1           1.000          1
#          rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 0    -0.314 0.583      -0.096       -0.921  0.896 -0.680             -0.928
# 144   2.345 0.488       0.093       -1.160  0.716  1.261             -0.063
# 1440 -0.148 0.583       0.755        0.271 -1.403 -1.056              0.586
# 2016  0.683 0.583      -1.468       -1.637  2.339  0.134             -0.063
#
#       Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 0           1.000          0   -1      0.495        -0.542         0.474
# 144         1.000          0   -1      0.495         1.001        -1.096
# 1440        1.000          0    1      0.528         0.486         0.082
# 2016        1.000          1    1      0.495         2.158        -0.311
#
#       Spcfc_Comorb  had_Prev_admin
# 0                0           0.000
# 144              1           1.000
# 1440             0           0.000
# 2016             1           1.000
# ==========================================================================================================
# ----------------------------------VALIDATION SET----------------------------------------------------------
# ==========================================================================================================
#     admission_id     rr  ews  heart_rate  temperature     sbp    dbp  \
# 0       59603192 26.000    6      77.000       38.100 145.000 55.000
# 144     33386907 18.000    1      87.000       36.700 129.000 75.000
# 288     80377128 22.000    6      87.000       36.200 100.000 71.000
# 432     26956465 24.000    3      91.000       36.800 116.000 49.000
#
#      Oxygen_Saturation  Assisted_O2  Confusion  sex  ethnicity  age_at_admin  \
# 0               96.000        1.000          0   -1          0            84
# 144             95.000        0.000          0    1          0            88
# 288             96.000        1.000          0    1          0            84
# 432            100.000        0.000          0    1         11            94
#
#      Comorb_score  Spcfc_Comorb  had_Prev_admin  Mortality
# 0              12             0           1.000          0
# 144             3             1           0.000          0
# 288             4             1           1.000          1
# 432             0             0           0.000          0
#         rr   ews  heart_rate  temperature    sbp    dbp  Oxygen_Saturation  \
# 0    0.351 0.585      -0.759        1.225  1.121 -0.806              0.370
# 144 -0.979 0.476      -0.286       -0.444  0.400  0.447              0.153
# 288 -0.314 0.585      -0.286       -1.041 -0.907  0.197              0.370
# 432  0.018 0.478      -0.096       -0.325 -0.186 -1.181              1.235
#
#      Assisted_O2  Confusion  sex  ethnicity  age_at_admin  Comorb_score  \
# 0          1.000          0   -1      0.495         0.101         1.259
# 144        0.000          0    1      0.495         0.615        -0.507
# 288        1.000          0    1      0.495         0.101        -0.311
# 432        0.000          0    1      0.000         1.386        -1.096
#
#      Spcfc_Comorb  had_Prev_admin
# 0               0           1.000
# 144             1           0.000
# 288             1           1.000
# 432             0           0.000
#               feature         type  \
# 0                  rr   Continuous
# 1                 ews  Categorical
# 2          heart_rate   Continuous
# 3         temperature   Continuous
# 4                 sbp   Continuous
# 5                 dbp   Continuous
# 6   Oxygen_Saturation   Continuous
# 7         Assisted_O2       Binary
# 8           Confusion       Binary
# 9                 sex       Binary
# 10          ethnicity  Categorical
# 11       age_at_admin   Continuous
# 12       Comorb_score   Continuous
# 13       Spcfc_Comorb       Binary
# 14     had_Prev_admin       Binary
#
#                                            parameters
# 0             [23.890862944162436, 6.016793103758225]
# 1        0   1  prob
# 8   10  14 0.583
# 7   22  21 0...
# 2             [93.03934010152284, 21.142804178258118]
# 3             [37.07258883248731, 0.8384888251493963]
# 4              [120.1256345177665, 22.18070196528276]
# 5             [67.86167512690355, 15.965389673159168]
# 6              [94.29060913705584, 4.622237226895378]
# 7
# 8
# 9
# 10        0    1  prob
# 0   162  159 0.495
# 3    17 ...
# 11             [83.21573604060913, 7.779182508472385]
# 12             [5.583756345177665, 5.095459247009708]
# 13
# 14

# %%
print("############### Results without encoding ##############")
results3     = train_grid_XGB_model(train_set, valid_set, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results without encoding ##############
# Best: 0.798462 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.605504 (0.580427) with: {'scale_pos_weight': 1}
# 0.593449 (0.597222) with: {'scale_pos_weight': 2}
# 0.595513 (0.629530) with: {'scale_pos_weight': 3}
# 0.593216 (0.661709) with: {'scale_pos_weight': 4}
# 0.588751 (0.678462) with: {'scale_pos_weight': 5}
# 0.580234 (0.670128) with: {'scale_pos_weight': 8}
# 0.595684 (0.736239) with: {'scale_pos_weight': 10}
# 0.591773 (0.749786) with: {'scale_pos_weight': 25}
# 0.589055 (0.758034) with: {'scale_pos_weight': 50}
# 0.593786 (0.780085) with: {'scale_pos_weight': 75}
# 0.590993 (0.786795) with: {'scale_pos_weight': 99}
# 0.589283 (0.769786) with: {'scale_pos_weight': 100}
# 0.583143 (0.798462) with: {'scale_pos_weight': 500}
#
# time elapased training:  1804.3079044818878
# Confidence interval for the score: [0.579 - 0.711]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.242   0.811     0.372     0.440 0.643  0.500  [0.58, 0.711]

# %%
print("############### Results encoded data ##############")
results3_enc = train_grid_XGB_model(train_set_norm, valid_set_norm, train_set, valid_set, grid, feat_list)
# Out:
# ############### Results encoded data ##############
# Best: 0.825855 using {'scale_pos_weight': 500}
# AUC    (call)
# 0.608387 (0.583718) with: {'scale_pos_weight': 1}
# 0.592568 (0.612350) with: {'scale_pos_weight': 2}
# 0.596360 (0.656667) with: {'scale_pos_weight': 3}
# 0.601956 (0.695427) with: {'scale_pos_weight': 4}
# 0.599258 (0.690598) with: {'scale_pos_weight': 5}
# 0.594877 (0.713803) with: {'scale_pos_weight': 8}
# 0.595279 (0.731026) with: {'scale_pos_weight': 10}
# 0.594150 (0.756282) with: {'scale_pos_weight': 25}
# 0.596671 (0.790256) with: {'scale_pos_weight': 50}
# 0.586958 (0.771453) with: {'scale_pos_weight': 75}
# 0.593382 (0.803675) with: {'scale_pos_weight': 99}
# 0.591061 (0.786838) with: {'scale_pos_weight': 100}
# 0.591625 (0.825855) with: {'scale_pos_weight': 500}
#
# time elapased training:  1821.59326338768
# Confidence interval for the score: [0.554 - 0.683]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.245   0.849     0.380     0.432 0.619  0.493  [0.55, 0.683]

# %% [markdown]
# # Results

# %% [markdown]
# # AUROC curve

# %%
title = 'Bal_XGB Classifier'
plt.figure()
colors = ['darkorange', 'b','g','r','c', 'm']
i = 0

results_encs =[results1_enc, results2_enc, results3_enc]

for results_enc in results_encs:
    df_results_valid = results_enc[1]
    dict_fpr_tpr     = results_enc[2]

    key = 'NoF'
    val = dict_fpr_tpr[key]
    auc = df_results_valid.loc[key,'AUC']
    rcl = df_results_valid.loc[key,'Recall']
    fpr, tpr = val

    lw = 2

    plt.plot(fpr,  tpr,  color= colors[i],  lw=lw,label= key + " auc = {:,.2f} recall = {:,.2f}".format(auc, rcl) 
        #label="ROC curve (area = %0.2f)" % metrics.roc_auc[2],
    )
    i = i + 1
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic "+ title)
plt.legend(loc="lower right")
#plt.savefig('AUROC_'+title+'.png', transparent = True, bbox_inches = "tight")
plt.show()

# %%
for r in results_encs:
    display(r[1])
# Out:
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.098   1.000     0.179     0.306 0.709  0.636  [0.63, 0.776]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.173   0.885     0.290     0.319 0.610  0.606  [0.54, 0.675]
#      Precision  Recall  F1_Score  Accuracy   AUC  brier         AUC_IC
# NoF      0.245   0.849     0.380     0.432 0.619  0.493  [0.55, 0.683]

# %%
pickle.dump([results_encs], open('dict_fpr_trp_'+title+'.pickle', 'wb'))
